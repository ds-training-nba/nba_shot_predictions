# %%
from datasets import load_dataset
import pandas as pd

# %%
# Load entire dataset
dataset = load_dataset("ds-training-nba/nba_shot_data")
# Out:
# Repo card metadata block was not found. Setting CardData to empty.

# %%
ds = load_dataset(
    "parquet",
    data_files="https://huggingface.co/datasets/ds-training-nba/nba_shot_data/resolve/main/raw_merged/merged_dataset.parquet"
)
df = ds["train"].to_pandas()
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
df.head()
# Out:
#            GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID         PLAYER_NAME  \
# 0  Shot Chart Detail  29600005              7        120        Steven Smith
# 1  Shot Chart Detail  29600005              9        120        Steven Smith
# 2  Shot Chart Detail  29600005             17        363  Christian Laettner
# 3  Shot Chart Detail  29600005             20        120        Steven Smith
# 4  Shot Chart Detail  29600005             21         87     Dikembe Mutombo
#
#       TEAM_ID      TEAM_NAME  PERIOD_x  MINUTES_REMAINING  SECONDS_REMAINING  \
# 0  1610612737  Atlanta Hawks         1                 11                  8
# 1  1610612737  Atlanta Hawks         1                 10                 32
# 2  1610612737  Atlanta Hawks         1                  9                 38
# 3  1610612737  Atlanta Hawks         1                  8                 57
# 4  1610612737  Atlanta Hawks         1                  8                 56
#
#    ... PLAYER3_ID PLAYER3_NAME PLAYER3_TEAM_ID PLAYER3_TEAM_CITY  \
# 0  ...        0.0          NaN             NaN               NaN
# 1  ...        0.0          NaN             NaN               NaN
# 2  ...        0.0          NaN             NaN               NaN
# 3  ...        0.0          NaN             NaN               NaN
# 4  ...        0.0          NaN             NaN               NaN
#
#   PLAYER3_TEAM_NICKNAME PLAYER3_TEAM_ABBREVIATION  VIDEO_AVAILABLE_FLAG  year  \
# 0                   NaN                       NaN                   0.0  1996
# 1                   NaN                       NaN                   0.0  1996
# 2                   NaN                       NaN                   0.0  1996
# 3                   NaN                       NaN                   0.0  1996
# 4                   NaN                       NaN                   0.0  1996
#
#    is_playoffs  shotValue
# 0        False        NaN
# 1        False        NaN
# 2        False        NaN
# 3        False        NaN
# 4        False        NaN
#
# [5 rows x 83 columns]
